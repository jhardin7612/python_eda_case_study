# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

raw_df = pd.read_csv('./data/health_nutrition.csv')
raw_df = raw_df.drop('Unnamed: 60', axis=1)

# %%
raw_df['2000']
# Out:
# 0              NaN
# 1              NaN
# 2        53.831410
# 3              NaN
# 4              NaN
#            ...
# 89005          NaN
# 89006          NaN
# 89007     0.000000
# 89008          NaN
# 89009    56.684974
# Name: 2000, Length: 89010, dtype: float64

# %%
# Out:
#                                      Country Name Country Code  \
# 0                                      Arab World          ARB
# 1                                      Arab World          ARB
# 2                                      Arab World          ARB
# 3                                      Arab World          ARB
# 4                                      Arab World          ARB
# ...                                           ...          ...
# 1995  East Asia & Pacific (excluding high income)          EAP
# 1996  East Asia & Pacific (excluding high income)          EAP
# 1997  East Asia & Pacific (excluding high income)          EAP
# 1998  East Asia & Pacific (excluding high income)          EAP
# 1999  East Asia & Pacific (excluding high income)          EAP
#
#                                          Indicator Name     Indicator Code  \
# 0     % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# ...

# %%
# Out:
# 345

# %%
grouped_indicator = raw_df.groupby('Indicator Name').value_counts()
grouped_indicator.head(20)
# Out:
# Indicator Name                                      Country Name                            Country Code  Indicator Code  1960        1961        1962        1963        1964        1965        1966        1967        1968        1969        1970        1971        1972        1973        1974        1975        1976        1977        1978        1979        1980        1981        1982       1983       1984       1985       1986       1987       1988       1989       1990        1991        1992        1993        1994        1995        1996        1997        1998        1999        2000        2001        2002        2003        2004        2005       2006       2007        2008        2009        2010       2011       2012       2013       2014       2015
# ...
